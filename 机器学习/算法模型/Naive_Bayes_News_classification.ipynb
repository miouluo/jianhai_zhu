# %%
from sklearn.datasets import fetch_20newsgroups_vectorized
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.datasets import load_files

# %%
def nb_news():
    #使用朴素贝叶斯算法对新闻进行分类
    # 1)获取数据
    # news = fetch_20newsgroups_vectorized(subset="all")
    
    # 获取数据
    news = load_files("./20news-18828", encoding="latin1")
    # 2)划分数据集
    x_train,x_test,y_train,y_test = train_test_split(news.data,news.target)
    
    # 3)特征工程：文本特征抽取-Tfidf
    transfer = TfidfVectorizer()
    x_train = transfer.fit_transform(x_train)
    
    x_train
    
    x_test = transfer.transform(x_test)
    print(x_test)
    
    # 4)朴素贝叶斯预估器流程
    estimator = MultinomialNB()
    estimator.fit(x_train,y_train)
    
    # 5)模型评估
    # 直接对比真实值和预测值
    y_predict = estimator.predict(x_test)
    print("y_predict\n", y_predict)
    print("真实值和预测值进行比对:\n", y_predict == y_test)

    # 计算准确率
    score = estimator.score(x_test, y_test)
    print("准确率为:\n", score)
    return None
    
#使用朴素贝叶斯算法对新闻进行分类
nb_news()
# Out:
#   (0, 144666)	0.06642869899643475
#   (0, 144344)	0.22135350541209206
#   (0, 136828)	0.10081806963238012
#   (0, 136008)	0.02234661201155696
#   (0, 135692)	0.015824311401044393
#   (0, 135673)	0.019859605045319258
#   (0, 135659)	0.04293063939054953
#   (0, 134320)	0.06481360390994122
#   (0, 131996)	0.014735353920878687
#   (0, 127187)	0.07877524613792196
#   (0, 127179)	0.07822211161130213
#   (0, 120362)	0.11738791802269663
#   (0, 120207)	0.0706794125122992
#   (0, 120166)	0.0790188112522381
#   (0, 110665)	0.036993726295111086
#   (0, 103519)	0.051374306280343764
#   (0, 103464)	0.03973901694837853
#   (0, 103252)	0.11379046698793242
#   (0, 96495)	0.12160946206775039
#   (0, 91306)	0.07653833081099445
#   (0, 79502)	0.10081806963238012
#   (0, 79166)	0.017296415988911386
#   (0, 79104)	0.08990248444915251
#   (0, 74248)	0.16282717039446032
#   (0, 74244)	0.10876581344919749
#   :	:
#   (4706, 91195)	0.06890511264131005
#   (4706, 90545)	0.08019509132729354
#   (4706, 90267)	0.044292683298967316
#   (4706, 89428)	0.07995760647706839
#   (4706, 84400)	0.3390657886607535
#   (4706, 81628)	0.12162550293130177
#   (4706, 80357)	0.13205261824631262
#   (4706, 79166)	0.04822505443710818
#   (4706, 76204)	0.04760618095506488
#   (4706, 74493)	0.06431206169216609
#   (4706, 67653)	0.02054221075163778
#   (4706, 57935)	0.10521242002141722
#   (4706, 52438)	0.3767110633086161
#   (4706, 49255)	0.15863261696628464
#   (4706, 48897)	0.13527450935052895
#   (4706, 48403)	0.13731005555621675
#   (4706, 48252)	0.10071845857180897
#   (4706, 44892)	0.06261980838219776
#   (4706, 43229)	0.11716165432947843
#   (4706, 41800)	0.1689781294175172
#   (4706, 39148)	0.03246418893578325
#   (4706, 39015)	0.11732277053384532
#   (4706, 35228)	0.08908928834537246
#   (4706, 34867)	0.06810886146568376
#   (4706, 34844)	0.041658569321878926
# y_predict
#  [13 18 17 ... 15 14  2]
# 真实值和预测值进行比对:
#  [ True  True  True ... False  True  True]
# 准确率为:
#  0.8372636498831527
